# %%
import scipy
import numpy as np

# %%
sample = np.linspace(0, 5,1000)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sample)

# %%
from sympy import symbols, solve

# %%
x=symbols('x', real=True)

# %%
solve(x**2-5*x + 1)
# Out:
# [5/2 - sqrt(21)/2, sqrt(21)/2 + 5/2]

# %%
A = np.array([[2,3],[1,2]], dtype= 'float')

# %%
A**-1
# Out:
# array([[0.5       , 0.33333333],
#        [1.        , 0.5       ]])

# %%
A*A.T
# Out:
# array([[4., 3.],
#        [3., 4.]])

# %%
A*A**-1
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
xvalues = np.linspace(-np.pi, np.pi)

# %%
plt.plot(xvalues)

# %%
yvalues = np.sin(xvalues)

# %%
plt.plot(xvalues, yvalues)
plt.axhline(0, lw=1.5, color='black')
plt.show()

# %%
from scipy import linalg

# %%
linalg.inv(A)
# Out:
# array([[ 2., -3.],
#        [-1.,  2.]])

# %%
linalg.lu(A)
# Out:
# (array([[1., 0.],
#         [0., 1.]]),
#  array([[1. , 0. ],
#         [0.5, 1. ]]),
#  array([[2. , 3. ],
#         [0. , 0.5]]))

# %%
import pandas_datareader as pdr

# %%
from pandas_datareader.wb import WorldBankReader

# %%
wb_reader = WorldBankReader()

# %%
wb_indicators = wb_reader.get_indicators()

# %%
wb_indicators[wb_indicators.topics=='Education ']
# Out:
#                                 id  \
# 113                    2.0.cov.FPS
# 138                    2.0.hoi.FPS
# 1167           BAR.NOED.1519.FE.ZS
# 1168              BAR.NOED.1519.ZS
# 1169           BAR.NOED.15UP.FE.ZS
# ...                            ...
# 16368                 UIS.TRTP.3.M
# 16455   UIS.XSPENDP.56.FDPUB.FNCAP
# 16456   UIS.XSPENDP.56.FDPUB.FNCUR
# 16457  UIS.XSPENDP.56.FDPUB.FNNONS
# 16459     UIS.XSPENDP.56.FDPUB.FNS
#
#                                                     name unit  \
# 113                    Coverage: Finished Primary School
# 138                         HOI: Finished Primary School
# 1167   Barro-Lee: Percentage of female population age...
# 1168   Barro-Lee: Percentage of population age 15-19 ...
# 1169   Barro-Lee: Percentage of female population age...
# ...                                                  ...  ...
# 16368  Proportion of teachers with the minimum requir...
# 16455  Capital expenditure as % of total expenditure ...
# ...

# %%
WorldBankReader().get_indicators().topics.unique()
# Out:
# array(['Poverty ', '', 'Education ', 'Social Protection & Labor',
#        'Economy & Growth', 'Agriculture & Rural Development  ',
#        'Agriculture & Rural Development   ; Climate Change',
#        'Agriculture & Rural Development   ; Climate Change ; Environment ',
#        'Climate Change ; Urban Development  ; Environment ',
#        'Climate Change ; Environment ',
#        'Agriculture & Rural Development   ; Environment ',
#        'Urban Development  ; Environment ',
#        'Economy & Growth ; Private Sector ; Trade',
#        'Economy & Growth ; Trade',
#        'Economy & Growth ; Science & Technology ',
#        'Economy & Growth ; External Debt ; Trade',
#        'Economy & Growth ; Financial Sector ',
#        'Economy & Growth ; External Debt', 'External Debt',
#        'Economy & Growth ; External Debt ; Aid Effectiveness ',
#        'Economy & Growth ; Infrastructure  ; Trade',
#        'Economy & Growth ; Financial Sector  ; External Debt',
# ...
