# %%
import yahoo_fin as yfin

# %%
import yahoo_fin as yfin
tickers = ['AAPL', 'MSFT','AMZN','WMT','XOM']
yfin.stock_info.get_analysts_info(tickers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 tickers = ['AAPL', 'MSFT','AMZN','WMT','XOM']
# ----> 2 yfin.stock_info.get_analysts_info(tickers)
#
# AttributeError: module 'yahoo_fin' has no attribute 'stock_info'

# %% [markdown]
# ![image.png](attachment:7fedb75f-ec0b-4d1c-a37e-3940afa38b68.png)

# %%
import yfinance as yf
yf.download

# %%
yf.download('AAPL', interval='1m').Close.plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Datetime'>
