# %%
# %matplotlib inline
import numpy as np
import torch
import requests
import pandas as pd
import yfinance as yf

# %%
stock_url = "https://api.nasdaq.com/api/screener/stocks?tableonly=true&limit=25&offset=0&download=true"
etf_url = "https://api.nasdaq.com/api/screener/etf?tableonly=true&limit=25&offset=0&download=true"
headers = {"Accept-Language":"en-US,en;q=0.9","Accept-Encoding":"gzip, deflate, br","User-Agent":"Java-http-client/"}

# %%
etf_response = requests.get(etf_url, headers=headers)
et_json = etf_response.json()
et_df = pd.DataFrame(et_json['data']['data']['rows'])

# %%
etf_tickers = yf.Tickers(list(et_df.symbol))
etf_details=[]
for k,v in list(etf_tickers.tickers.items()):
    try:
        aa=v.get_institutional_holders()
        etf_details.append(aa.set_index(0).T.assign(symbol=k))
        print("done for ",k)
    except Exception as e:
        print("error for ", k, len(etf_details))
# Out:
# done for  LOUP
# done for  LQD
# done for  LQDB
# done for  LQDH
# done for  LQDI
# done for  LQIG
# done for  LRGE
# done for  LRGF
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [19], line 5
#       3 for k,v in list(etf_tickers.tickers.items()):
#       4     try:
# ----> 5         aa=v.get_institutional_holders()
#       6         etf_details.append(aa.set_index(0).T.assign(symbol=k))
#       7         print("done for ",k)
#
# File ~/opt/anaconda3/envs/new_env/bin/lib/python3.9/site-packages/yfinance/base.py:679, in TickerBase.get_institutional_holders(self, proxy, as_dict, *args, **kwargs)
#     678 def get_institutional_holders(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 679     self._get_fundamentals(proxy=proxy)
#     680     data = self._institutional_holders
#     681     if data is not None:
#
# ...

# %%
pd.concat(etf_details)
# Out:
# 0 Net Assets     NAV PE Ratio (TTM)  Yield YTD Daily Total Return  \
# 1     41.52M   41.13          38.14  0.00%                 42.14%
# 1     36.99B  107.46          32.63  3.68%                  4.11%
# 1     25.21M   83.89            NaN  3.58%                  3.98%
# 1    251.34M   92.54            NaN  5.34%                  5.13%
# 1     60.63M   25.69            NaN  3.55%                  4.15%
# 1     28.61M   95.02            NaN  5.74%                  4.17%
# 1    149.56M   55.88          40.02  0.12%                 36.95%
# 1      1.35B   45.45          18.96  1.60%                 17.47%
#
# 0 Beta (5Y Monthly) Expense Ratio (net) Inception Date symbol
# 1              1.42               0.70%     2018-07-24   LOUP
# 1              1.59               0.14%     2002-07-22    LQD
# 1              0.00               0.15%     2021-05-18   LQDB
# 1              0.50               0.24%     2014-05-27   LQDH
# ...

# %%
yf.Ticker('SKY').get_institutional_holders()

# %%
yf.Ticker('AFK').history()
# Out:
#                             Open   High      Low  Close  Volume  Dividends  \
# Date
# 2023-06-20 00:00:00-04:00  15.30  15.30  14.9000  15.00   45200          0
# 2023-06-21 00:00:00-04:00  15.05  15.17  15.0200  15.09    6500          0
# 2023-06-22 00:00:00-04:00  15.05  15.05  14.7500  14.80   10500          0
# 2023-06-23 00:00:00-04:00  14.80  14.86  14.5300  14.68   17000          0
# 2023-06-26 00:00:00-04:00  14.80  15.05  14.8000  14.90    5800          0
# 2023-06-27 00:00:00-04:00  14.79  14.79  14.5700  14.79   12200          0
# 2023-06-28 00:00:00-04:00  14.99  14.99  14.5100  14.82   11500          0
# 2023-06-29 00:00:00-04:00  14.68  14.75  14.5700  14.70    8300          0
# 2023-06-30 00:00:00-04:00  14.75  14.78  14.5900  14.70   64600          0
# 2023-07-03 00:00:00-04:00  15.06  15.06  14.8900  14.93    5000          0
# 2023-07-05 00:00:00-04:00  15.00  15.00  14.6300  14.85    5100          0
# ...
