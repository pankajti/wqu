# %%
import numpy as np
weight = np.array([0,3,5])
xq=np.array([2,2,4])
delta_weight = .01*2*xq*-26
uweight = weight+delta_weight
np.dot(uweight , xq)
# Out:
# 13.52

# %%
import matplotlib.pyplot as plt

# %%
X = np.linspace(0,100,1000)
Y = list(map(lambda x : x**4-3*x**2 , X))
plt.plot(X,Y)

# %%
X = np.linspace(0,100,1000)
Y = list(map(lambda x : x**3 , X))
plt.plot(X,Y)

# %%
X = np.linspace(0,100,1000)
Y = list(map(lambda x : x**2 , X))
plt.plot(X,Y)

# %%
X = np.linspace(0,100,1000)
Y = list(map(lambda x : x , X))
plt.plot(X,Y)

# %%
list(np.arange(0,100,1000))
# Out:
# [0]
